# %% [markdown]
# # Computer Vision – Foot Traffic Analysis
#
# ## Objective
# The goal of this notebook is to build a computer vision module that detects
# and counts people in images collected from different camera zones.
#
# We use a pre-trained YOLO object detection model and fine-tune it on our dataset
# using transfer learning. The trained model is then used to count people per image
# and generate a foot traffic dataset for business analysis.
#
# Each subfolder represents a different camera zone.

# %%
import os
import cv2
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt

# %%
BASE_DIR = r"D:\raw\cv_foot_traffic"

YOLO_IMAGES = r"..\..\data\processed\yolo\images"
YOLO_LABELS = r"..\..\data\processed\yolo\labels"

os.makedirs(YOLO_IMAGES, exist_ok=True)
os.makedirs(YOLO_LABELS, exist_ok=True)

# %%
# Each folder corresponds to a camera zone and is processed independently.
zones = [z for z in os.listdir(BASE_DIR) if os.path.isdir(os.path.join(BASE_DIR, z))]
zones
# Out:
# ['1', '2', '41']

# %% [markdown]
# ### convert CVAT to YOLO

# %%
def convert_cvat_to_yolo(zone_path, zone_name):
    images_dir = os.path.join(zone_path, "images")
    xml_path = os.path.join(zone_path, "annotations.xml")

    # --- 1) Copy ALL images + create empty labels (negative samples) ---
    img_files = [f for f in os.listdir(images_dir) if f.lower().endswith((".png", ".jpg", ".jpeg"))]

    for img_name in img_files:
        src = os.path.join(images_dir, img_name)
        img = cv2.imread(src)
        if img is None:
            continue

        new_img_name = f"{zone_name}_{img_name}"
        out_img_path = os.path.join(YOLO_IMAGES, new_img_name)
        cv2.imwrite(out_img_path, img)

        # empty label by default
        label_path = os.path.join(YOLO_LABELS, os.path.splitext(new_img_name)[0] + ".txt")
        if not os.path.exists(label_path):
            open(label_path, "w").close()

    # --- 2) Parse annotations.xml and append boxes to the right label file ---
    if not os.path.exists(xml_path):
        print(f"[WARN] No annotations.xml for {zone_name}. Images are added as negatives only.")
        return

    tree = ET.parse(xml_path)
    root = tree.getroot()

    for track in root.findall("track"):
        for box in track.findall("box"):
            if box.attrib.get("outside", "0") == "1":
                continue

            frame = int(box.attrib["frame"])
            xtl = float(box.attrib["xtl"])
            ytl = float(box.attrib["ytl"])
            xbr = float(box.attrib["xbr"])
            ybr = float(box.attrib["ybr"])

            # --- Choose filename style depending on zone ---
            # Zone 41 uses: frame_000001.png (you said 0-indexed, so frame_000000 exists)
            if zone_name in ["41", "zone41", "Zone41"]:
                # Try png first, then jpg
                img_name = f"frame_{frame:06d}.png"
                img_path = os.path.join(images_dir, img_name)
                if not os.path.exists(img_path):
                    img_name = f"frame_{frame:06d}.jpg"
                    img_path = os.path.join(images_dir, img_name)
                    
            elif str(zone_name) in ["2", "zone2", "Zone2"]:
                img_name = f"second_frame_{frame:02d}.png"
                img_path = os.path.join(images_dir, img_name)
                if not os.path.exists(img_path):
                    img_name = f"second_frame_{frame:02d}.jpg"
                    img_path = os.path.join(images_dir, img_name)

            else:
                # zone 1 default
                img_name = f"first_frame_{frame:02d}.png"
                img_path = os.path.join(images_dir, img_name)
                if not os.path.exists(img_path):
                    img_name = f"first_frame_{frame:02d}.jpg"
                    img_path = os.path.join(images_dir, img_name)

            if not os.path.exists(img_path):
                continue

            img = cv2.imread(img_path)
            if img is None:
                continue
            h, w, _ = img.shape

            x_center = ((xtl + xbr) / 2) / w
            y_center = ((ytl + ybr) / 2) / h
            bw = (xbr - xtl) / w
            bh = (ybr - ytl) / h

            # labels correspond to the copied image name
            new_img_name = f"{zone_name}_{img_name}"
            label_path = os.path.join(YOLO_LABELS, os.path.splitext(new_img_name)[0] + ".txt")

            with open(label_path, "a") as f:
                f.write(f"0 {x_center} {y_center} {bw} {bh}\n")

# %%
for zone in zones:
    zone_path = os.path.join(BASE_DIR, zone)
    convert_cvat_to_yolo(zone_path, zone)

print("Conversion complete")
# Out:
# Conversion complete

# %% [markdown]
# make Yamel

# %%
data_yaml = """
path: ..\..\data\processed\yolo
train: images
val: images

nc: 1
names: ['person']
"""

with open(r"..\..\data\processed\yolo\data.yaml", "w") as f:
    f.write(data_yaml)

print("data.yaml created")
# Out:
# data.yaml created

# %%
from ultralytics import YOLO

model = YOLO(r"modules\cv_foot_traffic\yolov8n.pt")

model.train(
    data=r"..\..\data\processed\yolo\data.yaml",
    epochs=20,
    imgsz=640
)

# Due to the small dataset size, transfer learning is used to fine-tune a pre-trained YOLOv8 model.
# Out:
# New https://pypi.org/project/ultralytics/8.4.14 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.6  Python-3.11.4 torch-2.2.2+cpu CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=..\..\data\processed\yolo8\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=modules\cv_foot_traffic\yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\training\runs\detect\train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 26.36.5 MB/s, size: 306.1 KB)
# train: Scanning D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\labels... 178 images, 73 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 178/178 282.5it/s 0.6s0.1s
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_00.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_01.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_02.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_03.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_04.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_05.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_06.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_07.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_08.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_09.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_10.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_11.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_12.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_13.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_14.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_15.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_16.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_17.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_18.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_19.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_20.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_21.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_22.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_23.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_24.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_25.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_26.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_27.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_28.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_29.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_30.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_31.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_32.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_33.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_34.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_35.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_36.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_37.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_38.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_39.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_40.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_41.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_42.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_43.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_44.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_45.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_46.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_47.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_48.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_49.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_50.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_51.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_52.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_53.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_54.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_55.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_56.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_57.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_58.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_59.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_60.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_61.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_62.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_63.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000000.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000001.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000002.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000003.PNG: 45 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000004.PNG: 45 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000005.PNG: 45 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000006.PNG: 45 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000007.PNG: 45 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000008.PNG: 45 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000009.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000010.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000011.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000012.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000013.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000014.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000015.PNG: 44 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000016.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000017.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000018.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000019.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000020.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000021.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000022.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000023.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000024.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000025.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000026.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000027.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000028.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000029.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000030.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000031.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000032.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000033.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000034.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000035.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000036.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000037.PNG: 43 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000038.PNG: 42 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000039.PNG: 42 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\41_frame_000040.PNG: 42 duplicate labels removed
# train: New cache created: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\labels.cache
# val: Fast image access  (ping: 0.00.0 ms, read: 2440.6424.2 MB/s, size: 314.8 KB)
# val: Scanning D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\labels.cache... 178 images, 73 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 178/178  0.0s
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_00.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_01.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_02.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_03.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_04.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_05.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_06.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_07.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_08.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_09.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_10.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_11.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_12.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_13.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_14.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_15.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_16.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_17.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_18.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_19.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_20.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_21.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_22.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_23.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_24.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_25.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_26.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_27.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_28.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_29.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_30.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_31.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_32.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_33.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_34.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_35.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_36.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_37.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_38.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_39.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_40.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_41.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_42.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_43.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_44.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_45.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_46.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_47.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_48.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_49.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_50.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_51.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_52.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_53.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_54.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_55.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame_56.png: 1 duplicate labels removed
# train: D:\PROJECTS\project_updated_cv_yolo26_setup\modules\data\processed\yolo8\images\1_first_frame
#             0.77393,     0.77221,     0.77043,     0.76828,     0.76427,     0.76391,     0.76248,     0.76135,     0.76023,      0.7581,     0.75638,     0.75605,     0.75556,     0.75407,     0.75275,     0.75034,     0.74951,     0.74824,     0.74729,     0.74463,     0.74209,      0.7418,     0.74111,
#             0.73922,     0.73538,     0.73187,     0.73047,     0.72815,     0.72666,      0.7259,     0.72484,     0.72415,     0.72145,     0.72008,     0.71704,     0.71487,     0.71373,     0.71166,     0.71031,     0.70922,     0.70691,     0.70597,     0.70452,     0.70301,     0.70164,     0.70101,
#             0.69935,     0.69599,     0.69415,     0.69103,     0.68794,     0.68585,     0.68322,     0.67942,     0.67611,     0.67164,     0.67067,     0.66927,     0.66698,     0.66534,     0.66061,     0.65889,      0.6531,      0.6501,     0.64736,     0.64383,     0.64004,     0.63647,     0.63116,
#             0.62705,     0.62305,     0.62011,     0.61671,     0.61295,     0.60928,     0.60454,     0.60111,     0.59555,     0.59182,     0.58842,     0.58451,     0.58098,      0.5761,     0.57077,     0.56704,     0.56332,     0.56234,     0.55773,     0.55269,     0.54851,     0.54565,     0.54349,
#             0.53513,     0.52378,     0.51728,     0.51268,      0.5062,     0.50229,     0.49645,     0.48918,     0.47535,     0.46622,     0.45718,     0.45164,     0.44308,     0.43263,       0.423,     0.41413,     0.40643,     0.39349,     0.38372,     0.37258,     0.36274,     0.35294,      0.3418,
#             0.33205,     0.32238,     0.31583,     0.30213,     0.29298,     0.28358,     0.27227,     0.25834,     0.24691,     0.23108,     0.21664,     0.20327,     0.19144,     0.18287,     0.17353,     0.16121,     0.15376,     0.13935,     0.12827,     0.11821,     0.10965,    0.098906,    0.088097,
#            0.075984,    0.068803,    0.055932,    0.047141,    0.037831,    0.030604,    0.021241,    0.013223,    0.007067,   0.0012486,           0]]), 'Confidence', 'Recall']]
# fitness: 0.8582923768266933
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.85829])
# names: {0: 'person'}
# nt_per_class: array([1846], dtype=int64)
# nt_per_image: array([105], dtype=int64)
# results_dict: {'metrics/precision(B)': 0.9738224238674378, 'metrics/recall(B)': 0.9672971561088257, 'metrics/mAP50(B)': 0.9923602031864567, 'metrics/mAP50-95(B)': 0.8582923768266933, 'fitness': 0.8582923768266933}
# save_dir: WindowsPath('D:/PROJECTS/project_updated_cv_yolo26_setup/modules/cv_foot_traffic/training/runs/detect/train2')
# speed: {'preprocess': 1.7301719101064765, 'inference': 77.9005808988259, 'loss': 5.674167808270856e-05, 'postprocess': 13.361984831503374}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}
# task: 'detect'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
# %matplotlib inline
# Path to the results CSV file
results_path = 'runs/detect/train/results.csv'
df = pd.read_csv(results_path)

# Clean up column names (strip whitespace)
df.columns = df.columns.str.strip()

# Plot Training Loss vs Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['train/box_loss'], label='Train Box Loss')
plt.plot(df['epoch'], df['val/box_loss'], label='Val Box Loss')
plt.title('Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot mAP@0.5
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['metrics/mAP50-95(B)'], label='mAP@0.5-0.95')
plt.title('Mean Average Precision (mAP@0.5-0.95)')
plt.xlabel('Epochs')
plt.ylabel('mAP@0.5-0.95')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Create Heatmap

# %%
import numpy as np
from ultralytics import YOLO

heatmap_points = []
model= YOLO(r'best.pt')
for img_name in os.listdir(YOLO_IMAGES):
    if img_name[0] !='4':
        img_path = os.path.join(YOLO_IMAGES, img_name)
        results = model(img_path)

    for box in results[0].boxes.xyxy.cpu().numpy():
        x1, y1, x2, y2 = box
        cx = int((x1 + x2) / 2)
        cy = int((y1 + y2) / 2)
        heatmap_points.append((cx, cy))

len(heatmap_points)
# Out:
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_00.png: 480x640 1 person, 168.9ms
# Speed: 3.8ms preprocess, 168.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_01.png: 480x640 1 person, 108.8ms
# Speed: 1.4ms preprocess, 108.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_02.png: 480x640 1 person, 106.6ms
# Speed: 1.2ms preprocess, 106.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_03.png: 480x640 2 persons, 115.3ms
# Speed: 1.1ms preprocess, 115.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_04.png: 480x640 1 person, 105.7ms
# Speed: 1.7ms preprocess, 105.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_05.png: 480x640 1 person, 105.7ms
# Speed: 1.8ms preprocess, 105.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_06.png: 480x640 2 persons, 107.7ms
# Speed: 1.0ms preprocess, 107.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_07.png: 480x640 2 persons, 164.5ms
# Speed: 1.2ms preprocess, 164.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_08.png: 480x640 2 persons, 97.8ms
# Speed: 1.4ms preprocess, 97.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_09.png: 480x640 1 person, 102.0ms
# Speed: 1.2ms preprocess, 102.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_10.png: 480x640 1 person, 97.7ms
# Speed: 1.5ms preprocess, 97.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_11.png: 480x640 1 person, 109.3ms
# Speed: 1.3ms preprocess, 109.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_12.png: 480x640 1 person, 103.6ms
# Speed: 1.2ms preprocess, 103.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_13.png: 480x640 1 person, 97.6ms
# Speed: 1.5ms preprocess, 97.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_14.png: 480x640 1 person, 94.8ms
# Speed: 1.3ms preprocess, 94.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_15.png: 480x640 1 person, 103.9ms
# Speed: 1.2ms preprocess, 103.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_16.png: 480x640 1 person, 108.8ms
# Speed: 1.6ms preprocess, 108.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_17.png: 480x640 1 person, 104.4ms
# Speed: 1.4ms preprocess, 104.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_18.png: 480x640 1 person, 105.8ms
# Speed: 1.4ms preprocess, 105.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_19.png: 480x640 1 person, 117.3ms
# Speed: 1.3ms preprocess, 117.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_20.png: 480x640 1 person, 117.3ms
# Speed: 1.6ms preprocess, 117.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_21.png: 480x640 2 persons, 103.6ms
# Speed: 1.0ms preprocess, 103.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_22.png: 480x640 1 person, 101.1ms
# Speed: 15.5ms preprocess, 101.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_23.png: 480x640 2 persons, 110.6ms
# Speed: 1.2ms preprocess, 110.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_24.png: 480x640 2 persons, 115.4ms
# Speed: 1.2ms preprocess, 115.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_25.png: 480x640 2 persons, 115.1ms
# Speed: 1.5ms preprocess, 115.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_26.png: 480x640 1 person, 101.3ms
# Speed: 1.2ms preprocess, 101.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_27.png: 480x640 (no detections), 87.6ms
# Speed: 1.2ms preprocess, 87.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_28.png: 480x640 1 person, 94.9ms
# Speed: 1.1ms preprocess, 94.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_29.png: 480x640 1 person, 161.6ms
# Speed: 1.2ms preprocess, 161.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_30.png: 480x640 1 person, 117.7ms
# Speed: 1.5ms preprocess, 117.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_31.png: 480x640 1 person, 100.9ms
# Speed: 1.8ms preprocess, 100.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_32.png: 480x640 1 person, 103.6ms
# Speed: 1.4ms preprocess, 103.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_33.png: 480x640 (no detections), 111.7ms
# Speed: 1.6ms preprocess, 111.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_34.png: 480x640 (no detections), 121.8ms
# Speed: 1.6ms preprocess, 121.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_35.png: 480x640 (no detections), 118.3ms
# Speed: 1.9ms preprocess, 118.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_36.png: 480x640 1 person, 115.4ms
# Speed: 1.4ms preprocess, 115.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_37.png: 480x640 2 persons, 123.1ms
# Speed: 1.7ms preprocess, 123.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_38.png: 480x640 1 person, 114.9ms
# Speed: 1.6ms preprocess, 114.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_39.png: 480x640 1 person, 107.4ms
# Speed: 1.1ms preprocess, 107.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_40.png: 480x640 1 person, 105.7ms
# Speed: 16.6ms preprocess, 105.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_41.png: 480x640 1 person, 103.0ms
# Speed: 1.2ms preprocess, 103.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_42.png: 480x640 1 person, 105.1ms
# Speed: 1.8ms preprocess, 105.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_43.png: 480x640 1 person, 106.8ms
# Speed: 1.4ms preprocess, 106.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_44.png: 480x640 1 person, 163.6ms
# Speed: 1.5ms preprocess, 163.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_45.png: 480x640 1 person, 98.2ms
# Speed: 1.5ms preprocess, 98.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_46.png: 480x640 2 persons, 105.2ms
# Speed: 1.5ms preprocess, 105.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_47.png: 480x640 2 persons, 109.0ms
# Speed: 1.5ms preprocess, 109.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_48.png: 480x640 2 persons, 105.5ms
# Speed: 1.7ms preprocess, 105.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_49.png: 480x640 2 persons, 94.1ms
# Speed: 2.7ms preprocess, 94.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_50.png: 480x640 1 person, 90.1ms
# Speed: 1.3ms preprocess, 90.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_51.png: 480x640 1 person, 90.2ms
# Speed: 1.3ms preprocess, 90.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_52.png: 480x640 2 persons, 101.4ms
# Speed: 1.2ms preprocess, 101.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_53.png: 480x640 2 persons, 111.1ms
# Speed: 1.5ms preprocess, 111.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_54.png: 480x640 2 persons, 124.7ms
# Speed: 1.7ms preprocess, 124.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_55.png: 480x640 1 person, 109.9ms
# Speed: 2.2ms preprocess, 109.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_56.png: 480x640 1 person, 90.2ms
# Speed: 1.5ms preprocess, 90.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_57.png: 480x640 1 person, 95.9ms
# Speed: 1.6ms preprocess, 95.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_58.png: 480x640 1 person, 108.5ms
# Speed: 1.5ms preprocess, 108.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_59.png: 480x640 1 person, 99.0ms
# Speed: 1.5ms preprocess, 99.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_60.png: 480x640 1 person, 119.3ms
# Speed: 1.4ms preprocess, 119.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_61.png: 480x640 (no detections), 107.8ms
# Speed: 2.5ms preprocess, 107.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_62.png: 480x640 (no detections), 118.6ms
# Speed: 3.5ms preprocess, 118.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\1_first_frame_63.png: 480x640 (no detections), 119.8ms
# Speed: 1.2ms preprocess, 119.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_00.png: 480x640 (no detections), 166.0ms
# Speed: 1.5ms preprocess, 166.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_01.png: 480x640 (no detections), 106.1ms
# Speed: 1.3ms preprocess, 106.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_02.png: 480x640 (no detections), 118.7ms
# Speed: 1.5ms preprocess, 118.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_03.png: 480x640 (no detections), 109.7ms
# Speed: 1.4ms preprocess, 109.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_04.png: 480x640 (no detections), 105.4ms
# Speed: 1.7ms preprocess, 105.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_05.png: 480x640 (no detections), 106.2ms
# Speed: 1.1ms preprocess, 106.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_06.png: 480x640 (no detections), 106.5ms
# Speed: 1.2ms preprocess, 106.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_07.png: 480x640 (no detections), 109.8ms
# Speed: 1.6ms preprocess, 109.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_08.png: 480x640 (no detections), 122.3ms
# Speed: 1.5ms preprocess, 122.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_09.png: 480x640 (no detections), 104.1ms
# Speed: 1.4ms preprocess, 104.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_10.png: 480x640 (no detections), 125.5ms
# Speed: 1.3ms preprocess, 125.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_11.png: 480x640 (no detections), 108.9ms
# Speed: 1.3ms preprocess, 108.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_12.png: 480x640 (no detections), 103.6ms
# Speed: 1.5ms preprocess, 103.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_13.png: 480x640 (no detections), 100.0ms
# Speed: 1.5ms preprocess, 100.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_14.png: 480x640 (no detections), 118.3ms
# Speed: 1.1ms preprocess, 118.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_15.png: 480x640 (no detections), 107.4ms
# Speed: 1.4ms preprocess, 107.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_16.png: 480x640 (no detections), 101.0ms
# Speed: 1.4ms preprocess, 101.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_17.png: 480x640 (no detections), 101.6ms
# Speed: 1.1ms preprocess, 101.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_18.png: 480x640 (no detections), 121.8ms
# Speed: 1.5ms preprocess, 121.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_19.png: 480x640 (no detections), 116.1ms
# Speed: 1.2ms preprocess, 116.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_20.png: 480x640 (no detections), 101.9ms
# Speed: 1.9ms preprocess, 101.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_21.png: 480x640 (no detections), 101.8ms
# Speed: 1.2ms preprocess, 101.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_22.png: 480x640 (no detections), 116.5ms
# Speed: 1.3ms preprocess, 116.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_23.png: 480x640 (no detections), 102.1ms
# Speed: 1.2ms preprocess, 102.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_24.png: 480x640 (no detections), 99.3ms
# Speed: 1.2ms preprocess, 99.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_25.png: 480x640 (no detections), 99.5ms
# Speed: 1.5ms preprocess, 99.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_26.png: 480x640 (no detections), 179.7ms
# Speed: 3.1ms preprocess, 179.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_27.png: 480x640 (no detections), 104.3ms
# Speed: 1.3ms preprocess, 104.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_28.png: 480x640 (no detections), 107.7ms
# Speed: 1.2ms preprocess, 107.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_29.png: 480x640 (no detections), 112.7ms
# Speed: 1.2ms preprocess, 112.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_30.png: 480x640 (no detections), 113.0ms
# Speed: 1.1ms preprocess, 113.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_31.png: 480x640 (no detections), 108.7ms
# Speed: 2.1ms preprocess, 108.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_32.png: 480x640 (no detections), 102.6ms
# Speed: 2.5ms preprocess, 102.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_33.png: 480x640 (no detections), 102.4ms
# Speed: 1.2ms preprocess, 102.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_34.png: 480x640 (no detections), 107.1ms
# Speed: 1.4ms preprocess, 107.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_35.png: 480x640 (no detections), 112.7ms
# Speed: 1.1ms preprocess, 112.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_36.png: 480x640 (no detections), 105.7ms
# Speed: 1.4ms preprocess, 105.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_37.png: 480x640 (no detections), 118.6ms
# Speed: 1.2ms preprocess, 118.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_38.png: 480x640 (no detections), 107.1ms
# Speed: 1.8ms preprocess, 107.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_39.png: 480x640 (no detections), 104.6ms
# Speed: 1.2ms preprocess, 104.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_40.png: 480x640 (no detections), 107.5ms
# Speed: 3.2ms preprocess, 107.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_41.png: 480x640 (no detections), 132.0ms
# Speed: 1.5ms preprocess, 132.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_42.png: 480x640 (no detections), 110.7ms
# Speed: 1.2ms preprocess, 110.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_43.png: 480x640 (no detections), 115.3ms
# Speed: 1.6ms preprocess, 115.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_44.png: 480x640 (no detections), 117.7ms
# Speed: 1.1ms preprocess, 117.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_45.png: 480x640 (no detections), 196.8ms
# Speed: 1.2ms preprocess, 196.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_46.png: 480x640 (no detections), 130.9ms
# Speed: 1.4ms preprocess, 130.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_47.png: 480x640 (no detections), 106.2ms
# Speed: 4.2ms preprocess, 106.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_48.png: 480x640 (no detections), 110.4ms
# Speed: 1.9ms preprocess, 110.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_49.png: 480x640 (no detections), 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_50.png: 480x640 (no detections), 110.2ms
# Speed: 1.1ms preprocess, 110.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_51.png: 480x640 (no detections), 108.4ms
# Speed: 1.1ms preprocess, 108.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_52.png: 480x640 (no detections), 115.0ms
# Speed: 1.4ms preprocess, 115.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_53.png: 480x640 (no detections), 109.5ms
# Speed: 2.9ms preprocess, 109.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_54.png: 480x640 (no detections), 127.3ms
# Speed: 1.2ms preprocess, 127.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_55.png: 480x640 (no detections), 112.7ms
# Speed: 1.3ms preprocess, 112.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_56.png: 480x640 (no detections), 103.5ms
# Speed: 1.3ms preprocess, 103.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_57.png: 480x640 (no detections), 98.7ms
# Speed: 1.1ms preprocess, 98.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_58.png: 480x640 (no detections), 93.7ms
# Speed: 1.3ms preprocess, 93.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_59.png: 480x640 (no detections), 92.0ms
# Speed: 1.4ms preprocess, 92.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_60.png: 480x640 (no detections), 106.8ms
# Speed: 1.7ms preprocess, 106.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_61.png: 480x640 (no detections), 108.3ms
# Speed: 1.6ms preprocess, 108.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_62.png: 480x640 (no detections), 115.5ms
# Speed: 1.4ms preprocess, 115.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_63.png: 480x640 (no detections), 103.2ms
# Speed: 1.6ms preprocess, 103.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_64.png: 480x640 (no detections), 105.2ms
# Speed: 1.5ms preprocess, 105.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_65.png: 480x640 (no detections), 165.8ms
# Speed: 1.2ms preprocess, 165.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_66.png: 480x640 (no detections), 119.6ms
# Speed: 1.1ms preprocess, 119.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_67.png: 480x640 (no detections), 102.6ms
# Speed: 1.3ms preprocess, 102.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_68.png: 480x640 (no detections), 110.8ms
# Speed: 1.4ms preprocess, 110.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_69.png: 480x640 (no detections), 115.1ms
# Speed: 1.3ms preprocess, 115.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_70.png: 480x640 (no detections), 93.5ms
# Speed: 1.6ms preprocess, 93.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_71.png: 480x640 (no detections), 94.7ms
# Speed: 1.2ms preprocess, 94.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 d:\PROJECTS\project_updated_cv_yolo26_setup\modules\cv_foot_traffic\..\..\data\processed\yolo\images\2_second_frame_72.png: 480x640 (no detections), 104.5ms
# Speed: 1.9ms preprocess, 104.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# 73

# %%
# Read one image to get dimensions
sample_img = cv2.imread(os.path.join(YOLO_IMAGES, os.listdir(YOLO_IMAGES)[0]))
h, w, _ = sample_img.shape

heatmap = np.zeros((h, w), dtype=np.float32)

for (x, y) in heatmap_points:
    if 0 <= x < w and 0 <= y < h:
        heatmap[y, x] += 1
        
heatmap = cv2.GaussianBlur(heatmap, (51, 51), 0)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(heatmap, cmap="hot")
plt.colorbar(label="People Density")
plt.title("Customer Foot Traffic Heatmap")
plt.axis("off")
plt.show()

# %%
norm_heatmap = cv2.normalize(heatmap, None, 0, 255, cv2.NORM_MINMAX)
norm_heatmap = norm_heatmap.astype(np.uint8)

colored_heatmap = cv2.applyColorMap(norm_heatmap, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(sample_img, 0.6, colored_heatmap, 0.4, 0)

plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.title("Heatmap Overlay on Store Image")
plt.axis("off")
plt.show()
